# %% [markdown]
# # Digital Library Reference Number API

# %% [markdown]
# The Digital Library has an API endpoint that allows us to obtain full records using an item's reference number.

# %%
import requests
import json

# %%
# function that takes a url with query params to an endpoint
def get_data(url):
    resp = requests.get(url)
    if resp.status_code == 200:
        return resp.json()
    else:
        print(f'Request failed with {resp.status_code} error code')

# %%
# let's start by searching for a record by reference number

ref_number = 'ao-hartley1746430-2001'# the reference number uniquely identifies records in viewer.soton.ac.uk
ref_number_url = f'https://api.epexio.com/catalogues/uosViewer/public/descriptions?refNo={ref_number}'

data = get_data(ref_number_url)
pretty_print_record_data = json.dumps(data, indent=4)
print(pretty_print_record_data)
# Out:
# {
#     "refNo": "ao-hartley1746430-2001",
#     "uri": "http://data.epexio.com/uosViewer/descriptions/70024348-1db5-4dbd-9de8-e468a43bcdce",
#     "id": "70024348-1db5-4dbd-9de8-e468a43bcdce",
#     "status": "catalogued",
#     "public": true,
#     "publicStatus": "true",
#     "title": "1937-38 University College Southampton. Students' Council & Union minute book",
#     "fields": [
#         {
#             "displayPosition": 2,
#             "fieldUri": "http://schema.epexio.com/extended/1.0/primaryCategory",
#             "values": [
#                 {
#                     "text": "SUSU Records",
#                     "id": "7bdb8282-f3a7-4522-8ce6-0d3fbcafb318",
#                     "anc": null,
#                     "titles": [
#                         {
#                             "lang": "en",
#                             "val": "SUSU Records"
#                         }
#                     ],
#                     "type": "subjects"
#                 }
#             ],
#             "displayName_en": "Collection",
#             "displayName": "Collection",
#             "namespacedPredicate": "ext:primaryCategory"
#         },
#         {
#             "displayPosition": 3,
#             "fieldUri": "http://schema.epexio.com/extended/1.0/complexDate",
#             "values": [
#                 {
#                     "inlineEntity": true,
#                     "inlineType": "complexDate",
#                     "inlineValues": {
#                         "uri": "http://data.epexio.com/uosViewer/dates/053895ef-2b69-4add-9f12-238198972295",
#                         "type": "http://schema.epexio.com/entities/Date",
#                         "date": "1938",
#                         "dateType": null
#                     }
#                 }
#             ],
#             "displayName_en": "Date(s)",
#             "displayName": "Date(s)",
#             "namespacedPredicate": "ext:complexDate"
#         },
#         {
#             "displayPosition": 6,
#             "fieldUri": "http://purl.org/dc/elements/1.1/creator",
#             "values": [
#                 "University College, Southampton. Students' Council"
#             ],
#             "displayName_en": "Creator",
#             "displayName": "Creator",
#             "namespacedPredicate": "http://purl.org/dc/elements/1.1/creator"
#         },
#         {
#             "displayPosition": 9,
#             "fieldUri": "http://purl.org/dc/elements/1.1/rights",
#             "values": [
#                 "http://creativecommons.org/licenses/by-nc-nd/3.0/"
#             ],
#             "displayName_en": "Rights",
#             "displayName": "Rights",
#             "namespacedPredicate": "http://purl.org/dc/elements/1.1/rights"
#         },
#         {
#             "displayPosition": 11,
#             "fieldUri": "http://purl.org/dc/elements/1.1/description",
#             "values": [
#                 "\"From November 23rd 1937. To June 28th 1938.\"--T.p.\nView the full catalogue record: https://southampton.on.worldcat.org/oclc/1333212171."
#             ],
#             "displayName_en": "Description",
#             "displayName": "Description",
#             "namespacedPredicate": "http://purl.org/dc/elements/1.1/description"
#         },
#         {
#             "displayPosition": 13,
#             "fieldUri": "http://purl.org/dc/elements/1.1/coverage",
#             "values": [
#                 "1 online resource (1 v.)"
#             ],
#             "displayName_en": "Coverage",
#             "displayName": "Coverage",
#             "namespacedPredicate": "http://purl.org/dc/elements/1.1/coverage"
#         },
#         {
#             "displayPosition": 14,
#             "fieldUri": "http://purl.org/dc/elements/1.1/language",
#             "values": [
#                 "eng"
#             ],
#             "displayName_en": "Language",
#             "displayName": "Language",
#             "namespacedPredicate": "http://purl.org/dc/elements/1.1/language"
#         }
#     ],
#     "item": {
#         "uri": "http://data.epexio.com/uosViewer/descriptions/70024348-1db5-4dbd-9de8-e468a43bcdce",
#         "id": "70024348-1db5-4dbd-9de8-e468a43bcdce",
#         "thumb": false,
#         "itemIcon": "fa-files-o",
#         "refNo": "ao-hartley1746430-2001",
#         "publicRefNo": "ao-hartley1746430-2001",
#         "recordTitle": "1937-38 University College Southampton. Students' Council & Union minute book",
#         "date": "1938",
#         "level": "",
#         "ancestors": [],
#         "ancestorsExist": false,
#         "recordClass": "description",
#         "exhibitions": [],
#         "sourceDataset": "descriptions",
#         "recordLocation": null,
#         "accessCategories": [
#             "true"
#         ],
#         "primaryCategory": [
#             "http://data.epexio.com/uosViewer/subjects/7bdb8282-f3a7-4522-8ce6-0d3fbcafb318"
#         ],
#         "title": "1937-38 University College Southampton. Students' Council & Union minute book",
#         "icon": "fa-files-o",
#         "recordClassLabel": "",
#         "descendentsExist": false,
#         "depth": 1,
#         "treeEditedAt": null,
#         "editedAt": "2023-07-11T14:10:31.691Z",
#         "isCollection": true,
#         "collectionTitle": "1937-38 University College Southampton. Students' Council & Union minute book",
#         "publicStatus": "true",
#         "isPublic": true,
#         "status": "catalogued"
#     },
#     "digitisation": {
#         "uri": "http://data.epexio.com/uosViewer/digitisations/ea387d1d-2511-4f97-b6b0-6bc6a8e59620",
#         "mode": "v8",
#         "delegateKey": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJkaWciOiJodHRwOi8vZGF0YS5lcGV4aW8uY29tL3Vvc1ZpZXdlci9kaWdpdGlzYXRpb25zL2VhMzg3ZDFkLTI1MTEtNGY5Ny1iNmIwLTZiYzZhOGU1OTYyMCIsImNhdGFsb2d1ZUlkIjoidW9zVmlld2VyIiwicXVhbGl0aWVzIjpbIioiXSwiaWF0IjoxNzUzOTUyNzk0LCJleHAiOjE3NTM5NTYzOTR9.sIfwkb6Y3jqtktbPbobWqdQYvTCOqNQVyiE9z2eQOBc",
#         "deliveryOptions": [
#             "downloadable",
#             "embeddable"
#         ],
#         "access": "urn:x-epexio:accessLevel/public",
#         "viewer": "urn:x-epexio:viewers/multipage",
#         "searchable": true
#     },
#     "altDigitisation": null,
#     "catalogueMessage": null,
#     "fieldProfile": "description_dublinCore",
#     "locator": "epexio:loc:uosViewer:descriptions/ao-hartley1746430-2001",
#     "pluralisedType": "descriptions",
#     "findingAids": [],
#     "publicAttachments": [],
#     "rdf": {
#         "@context": {
#             "ec": "http://schema.epexio.com/core/1.0/",
#             "isadg": "http://schema.epexio.com/isadg/1.0/",
#             "ext": "http://schema.epexio.com/extended/1.0/"
#         },
#         "@id": "http://data.epexio.com/uosViewer/descriptions/70024348-1db5-4dbd-9de8-e468a43bcdce",
#         "@type": "http://schema.epexio.com/entities/Description",
#         "ec:title": "1937-38 University College Southampton. Students' Council & Union minute book",
#         "ec:refNo": "ao-hartley1746430-2001",
#         "ec:publicRefNo": "ao-hartley1746430-2001",
#         "ext:collection": "1937-38 University College Southampton. Students' Council & Union minute book",
#         "ext:primaryCategory": {
#             "text": "SUSU Records",
#             "id": "7bdb8282-f3a7-4522-8ce6-0d3fbcafb318",
#             "anc": null,
#             "titles": [
#                 {
#                     "lang": "en",
#                     "val": "SUSU Records"
#                 }
#             ],
#             "type": "subjects"
#         },
#         "ext:complexDate": {
#             "inlineEntity": true,
#             "inlineType": "complexDate",
#             "inlineValues": {
#                 "uri": "http://data.epexio.com/uosViewer/dates/053895ef-2b69-4add-9f12-238198972295",
#                 "type": "http://schema.epexio.com/entities/Date",
#                 "date": "1938",
#                 "dateType": null
#             }
#         },
#         "http://purl.org/dc/elements/1.1/creator": "University College, Southampton. Students' Council",
#         "http://purl.org/dc/elements/1.1/rights": "http://creativecommons.org/licenses/by-nc-nd/3.0/",
#         "http://purl.org/dc/elements/1.1/description": "\"From November 23rd 1937. To June 28th 1938.\"--T.p.\nView the full catalogue record: https://southampton.on.worldcat.org/oclc/1333212171.",
#         "http://purl.org/dc/elements/1.1/coverage": "1 online resource (1 v.)",
#         "http://purl.org/dc/elements/1.1/language": "eng"
#     },
#     "discover": {
#         "path": "records/70024348-1db5-4dbd-9de8-e468a43bcdce",
#         "catalogue": "https://viewer.soton.ac.uk/",
#         "url": "https://viewer.soton.ac.uk/records/70024348-1db5-4dbd-9de8-e468a43bcdce",
#         "description": "\"From November 23rd 1937. To June 28th 1938.\"--T.p.\nView the full catalogue record: https://southampton.on.worldcat.org/oclc/1333212171."
#     }
# }

# %% [markdown]
# The reference number API endpoint returns the full record of a valid reference number in JSON. We can see the "fields" key contains quite a few metadata fields. Let's loop through the fields to find and print the values in the "Creator" field.

# %%
for field in data['fields']:
    if field['displayName'] == 'Creator':
        for value in field['values']:
            print(f'Creator: {value}')
# Out:
# Creator: University College, Southampton. Students' Council

# %% [markdown]
# Let's get the title and then print out all of the fields.

# %%
title = data['title']
print(f'Title: {title}')
for field in data['fields']:
    label = field['displayName']
    for value in field['values']:
        if label == 'Collection':# the collection field contains additional data but we only want the text
            v = value['text']
            print(f'{label}: {v}')
        elif label == 'Date(s)':# the date field contains additional data but we only need the date
            v = value['inlineValues']['date']
        else:
            print(f'{label}: {value}')
# Out:
# Title: 1937-38 University College Southampton. Students' Council & Union minute book
# Collection: SUSU Records
# Creator: University College, Southampton. Students' Council
# Rights: http://creativecommons.org/licenses/by-nc-nd/3.0/
# Description: "From November 23rd 1937. To June 28th 1938."--T.p.
# View the full catalogue record: https://southampton.on.worldcat.org/oclc/1333212171.
# Coverage: 1 online resource (1 v.)
# Language: eng
